# %%
import pandas as pd

# %%
# fonte
# https://www.dadosmundiais.com/america/brasil/clima.php


dados_climaticos = """Região	Temperatura máx Ø dia	Temperatura máx Ø noite	Horas de sol	Dias dechuva	Precipitação	Umidade
Acre	31,8 °C	21,5 °C	1.898 h	133	1.880 l	85,0 %
Alagoas	30,6 °C	22,0 °C	2.738 h	95	796 l	
Amapá	32,3 °C	24,3 °C	2.482 h	149	2.237 l	83,0 %
Amazonas	32,3 °C	23,3 °C	1.825 h	158	2.482 l	83,0 %
Bahia	30,3 °C	20,4 °C	2.592 h	88	1.026 l	81,0 %
Ceará	32,6 °C	22,9 °C	2.811 h	78	1.040 l	78,0 %
Distrito Federal	27,5 °C	17,0 °C	2.446 h	101	1.683 l	68,0 %
Espírito Santo	29,7 °C	21,2 °C	2.227 h	100	1.256 l	77,0 %
Goiás	29,4 °C	18,6 °C	2.482 h	98	1.482 l	68,0 %
Maranhão	33,4 °C	23,2 °C	2.519 h	98	1.529 l	77,0 %
Mato Grosso	32,6 °C	20,5 °C	2.154 h	98	1.533 l	
Mato Grosso do Sul	30,2 °C	18,8 °C	2.519 h	85	1.420 l	72,0 %
Minas Gerais	28,7 °C	18,4 °C	2.373 h	90	1.314 l	72,0 %
Pará	32,4 °C	23,4 °C	2.263 h	150	2.281 l	85,0 %
Paraíba	31,4 °C	22,7 °C	2.811 h	114	1.296 l	80,0 %
Paraná	27,1 °C	16,2 °C	2.227 h	98	1.624 l	82,0 %
Pernambuco	31,3 °C	22,2 °C	2.811 h	94	1.088 l	80,0 %
Piauí	33,5 °C	23,6 °C	2.628 h	96	1.460 l	77,0 %
Rio de Janeiro	29,2 °C	19,7 °C	1.971 h	80	1.219 l	
Rio Grande do Norte	31,8 °C	23,0 °C	3.066 h	91	1.226 l	
Rio Grande do Sul	25,2 °C	14,7 °C	2.373 h	86	1.464 l	74,0 %
Rondônia	32,0 °C	21,2 °C	2.081 h	112	1.708 l	
Roraima	33,7 °C	24,4 °C	2.263 h	119	1.613 l	72,0 %
Santa Catarina	25,9 °C	17,3 °C	2.117 h	121	1.657 l	82,0 %
São Paulo	28,5 °C	17,6 °C	2.373 h	94	1.402 l	78,0 %
Sergipe	30,3 °C	23,0 °C	2.811 h	110	975 l	78,0 %
Tocantins	33,5 °C	22,3 °C	2.373 h	103	1.683 l	


"""

# %%
from io import StringIO
dados_climaticos_io = StringIO(dados_climaticos)

# %%
clima_chuva = pd.read_csv(dados_climaticos_io, sep="\t")

# %%
clima_chuva
# Out:
#                  Região Temperatura máx Ø dia Temperatura máx Ø noite  \
# 0                  Acre               31,8 °C                 21,5 °C
# 1               Alagoas               30,6 °C                 22,0 °C
# 2                 Amapá               32,3 °C                 24,3 °C
# 3              Amazonas               32,3 °C                 23,3 °C
# 4                 Bahia               30,3 °C                 20,4 °C
# 5                 Ceará               32,6 °C                 22,9 °C
# 6      Distrito Federal               27,5 °C                 17,0 °C
# 7        Espírito Santo               29,7 °C                 21,2 °C
# 8                 Goiás               29,4 °C                 18,6 °C
# 9              Maranhão               33,4 °C                 23,2 °C
# 10          Mato Grosso               32,6 °C                 20,5 °C
# 11   Mato Grosso do Sul               30,2 °C                 18,8 °C
# ...

# %%
metereologico = pd.read_csv('fase1/dados/metereologicos/dados_82024_M_2008-01-01_2022-12-31.csv', sep=";")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_267477/2338573597.py in <module>
# ----> 1 metereologico = pd.read_csv('fase1/dados/metereologicos/dados_82024_M_2008-01-01_2022-12-31.csv', sep=";")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
