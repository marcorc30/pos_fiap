# %%
import pandas as pd

# %%
impVinhos = pd.read_csv('dados/ImpVinhos.csv', sep=";")

# %%
impVinhos.head(10)
# Out:
#    Id            País   1970    1970.1   1971  1971.1    1972  1972.1    1973  \
# 0   1   Africa do Sul      0      0.00      0       0       0       0       0
# 1   2        Alemanha  52297 30,498.00  34606   26027  134438   92103  111523
# 2   3         Argélia      0      0.00      0       0       0       0       0
# 3   4  Arábia Saudita      0      0.00      0       0       0       0       0
# 4   5       Argentina  19525 12,260.00  24942   15022  104906   58137  116887
# 5   6         Armênia      0      0.00      0       0       0       0       0
# 6   7       Austrália      0      0.00      0       0       0       0       0
# 7   8         Áustria   1328    707.00      0       0     353     520    2310
# 8   9        Bermudas      0       NaN      0       0       0       0       0
# 9  10         Bélgica      0      0.00      0       0       0       0       0
#
#    1973.1  ...      2018    2018.1      2019    2019.1      2020    2020.1  \
# ...

# %%
#colunas = impVinhos.columns.to_list()

argentina = impVinhos.query('País == "Argentina"')[colunas[62:]]

# %%
type(argentina)
# Out:
# pandas.core.frame.DataFrame

# %%
argentina2.isna().value_counts()
# Out:
# False    108
# Name: 4, dtype: int64

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
argentina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 4 to 4
# Data columns (total 46 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2000    1 non-null      int64
#  1   2000.1  1 non-null      int64
#  2   2001    1 non-null      int64
#  3   2001.1  1 non-null      int64
#  4   2002    1 non-null      int64
#  5   2002.1  1 non-null      int64
#  6   2003    1 non-null      int64
#  7   2003.1  1 non-null      int64
#  8   2004    1 non-null      int64
#  9   2004.1  1 non-null      int64
#  10  2005    1 non-null      int64
#  11  2005.1  1 non-null      int64
#  12  2006    1 non-null      int64
#  13  2006.1  1 non-null      int64
#  14  2007    1 non-null      int64
#  15  2007.1  1 non-null      int64
#  16  2008    1 non-null      int64
#  17  2008.1  1 non-null      int64
#  18  2009    1 non-null      int64
#  19  2009.1  1 non-null      int64
#  20  2010    1 non-null      int64
#  21  2010.1  1 non-null      int64
# ...

# %%
totalEmbrapa = argentina.sum(axis = 1)

# %%
argentinaMdic = pd.read_csv('dados/IMP_2000_2022_20230831.csv', sep=",")
argentinaMdic = argentinaMdic.query('Country == "Argentina" ').groupby('Country').sum()

# %%
argentinaMdic
# Out:
#            NCM Code  2022 - US$ FOB  2022 - Net Weight  2022 - Quantity  \
# Country
# Argentina  88170830        87381601           27933534         27897816
#
#            2021 - US$ FOB  2021 - Net Weight  2021 - Quantity  2020 - US$ FOB  \
# Country
# Argentina        79383437           26753452         26707668        66287662
#
#            2020 - Net Weight  2020 - Quantity  ...  2003 - Quantity  \
# Country                                        ...
# Argentina           22588951         22578666  ...          5547057
#
#            2002 - US$ FOB  2002 - Net Weight  2002 - Quantity  2001 - US$ FOB  \
# Country
# Argentina         6884837            3865668          3810130         6196286
#
#            2001 - Net Weight  2001 - Quantity  2000 - US$ FOB  \
# Country
# Argentina            2585533          2569979         6563482
#
#            2000 - Net Weight  2000 - Quantity
# Country
# Argentina            2744752          2674564
#
# [1 rows x 70 columns]

# %%
colunasValor = []
for valor in argentinaMdic.columns:
    if valor.find('US$') != -1:
        colunasValor.append(valor)
    
colunasValor
# Out:
# ['2022 - US$ FOB',
#  '2021 - US$ FOB',
#  '2020 - US$ FOB',
#  '2019 - US$ FOB',
#  '2018 - US$ FOB',
#  '2017 - US$ FOB',
#  '2016 - US$ FOB',
#  '2015 - US$ FOB',
#  '2014 - US$ FOB',
#  '2013 - US$ FOB',
#  '2012 - US$ FOB',
#  '2011 - US$ FOB',
#  '2010 - US$ FOB',
#  '2009 - US$ FOB',
#  '2008 - US$ FOB',
#  '2007 - US$ FOB',
#  '2006 - US$ FOB',
#  '2005 - US$ FOB',
#  '2004 - US$ FOB',
#  '2003 - US$ FOB',
#  '2002 - US$ FOB',
#  '2001 - US$ FOB',
#  '2000 - US$ FOB']

# %%
argentinaMdic = argentinaMdic[colunasValor]

# %%
argentinaMdic
# Out:
#            2022 - US$ FOB  2021 - US$ FOB  2020 - US$ FOB  2019 - US$ FOB  \
# Country
# Argentina        87381601        79383437        66287662        54511669
#
#            2018 - US$ FOB  2017 - US$ FOB  2016 - US$ FOB  2015 - US$ FOB  \
# Country
# Argentina        52817653        51722763        45214862        48043210
#
#            2014 - US$ FOB  2013 - US$ FOB  ...  2009 - US$ FOB  \
# Country                                    ...
# Argentina        53814455        49524670  ...        38525701
#
#            2008 - US$ FOB  2007 - US$ FOB  2006 - US$ FOB  2005 - US$ FOB  \
# Country
# Argentina        37382580        35703626        25347970        21463435
#
#            2004 - US$ FOB  2003 - US$ FOB  2002 - US$ FOB  2001 - US$ FOB  \
# Country
# Argentina        17049751         9618689         6884837         6196286
#
#            2000 - US$ FOB
# Country
# Argentina         6563482
#
# [1 rows x 23 columns]

# %%
totalMdic = argentinaMdic.sum(axis=1)

# %%
totalMdic = totalMdic[0].astype(float)

# %%
type(totalEmbrapa[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
totalMdic
# Out:
# 960010442.0
